# %% [markdown]
# # performance
# > Exploring the signal generation options

# %% [markdown]
# # Data
# Download the data so that we have something to work with

# %%
#|output: false
! ../scripts/download.sh
# Out:
# Downloading market data (~200 MB)
# --2024-03-04 11:09:46--  https://datasets.tardis.dev/v1/bybit/trades/2023/01/01/XRPUSDT.csv.gz
# Resolving datasets.tardis.dev (datasets.tardis.dev)... 104.18.40.205, 172.64.147.51
# Connecting to datasets.tardis.dev (datasets.tardis.dev)|104.18.40.205|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1338512 (1.3M) [text/csv]
# Saving to: ‘marketdata/20230101.XRP.csv.gz’
#
# marketdata/20230101 100%[===================>]   1.28M  8.24MB/s    in 0.2s
#
# 2024-03-04 11:09:47 (8.24 MB/s) - ‘marketdata/20230101.XRP.csv.gz’ saved [1338512/1338512]
#
# --2024-03-04 11:09:47--  https://datasets.tardis.dev/v1/bybit/trades/2023/01/01/OPUSDT.csv.gz
# Resolving datasets.tardis.dev (datasets.tardis.dev)... 104.18.40.205, 172.64.147.51
# Connecting to datasets.tardis.dev (datasets.tardis.dev)|104.18.40.205|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 415897 (406K) [text/csv]
# Saving to: ‘marketdata/20230101.OP.csv.gz’
#
# marketdata/20230101 100%[===================>] 406.15K  --.-KB/s    in 0.06s
#
# 2024-03-04 11:09:48 (7.12 MB/s) - ‘marketdata/20230101.OP.csv.gz’ saved [415897/415897]
#
# --2024-03-04 11:09:48--  https://datasets.tardis.dev/v1/bybit/trades/2023/01/01/MATICUSDT.csv.gz
# Resolving datasets.tardis.dev (datasets.tardis.dev)... 104.18.40.205, 172.64.147.51
# Connecting to datasets.tardis.dev (datasets.tardis.dev)|104.18.40.205|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 831791 (812K) [text/csv]
# Saving to: ‘marketdata/20230101.MATIC.csv.gz’
#
# marketdata/20230101 100%[===================>] 812.30K  --.-KB/s    in 0.1s
#
# 2024-03-04 11:09:48 (7.11 MB/s) - ‘marketdata/20230101.MATIC.csv.gz’ saved [831791/831791]
#
# --2024-03-04 11:09:48--  https://datasets.tardis.dev/v1/bybit/trades/2023/02/01/XRPUSDT.csv.gz
# Resolving datasets.tardis.dev (datasets.tardis.dev)... 104.18.40.205, 172.64.147.51
# Connecting to datasets.tardis.dev (datasets.tardis.dev)|104.18.40.205|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4146440 (4.0M) [text/csv]
# Saving to: ‘marketdata/20230201.XRP.csv.gz’
#
# marketdata/20230201 100%[===================>]   3.95M  9.83MB/s    in 0.4s
#
# 2024-03-04 11:09:49 (9.83 MB/s) - ‘marketdata/20230201.XRP.csv.gz’ saved [4146440/4146440]
#
# --2024-03-04 11:09:49--  https://datasets.tardis.dev/v1/bybit/trades/2023/02/01/OPUSDT.csv.gz
# Resolving datasets.tardis.dev (datasets.tardis.dev)... 104.18.40.205, 172.64.147.51
# Connecting to datasets.tardis.dev (datasets.tardis.dev)|104.18.40.205|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13236391 (13M) [text/csv]
# Saving to: ‘marketdata/20230201.OP.csv.gz’
#
# marketdata/20230201 100%[===================>]  12.62M  10.3MB/s    in 1.2s
#
# 2024-03-04 11:09:51 (10.3 MB/s) - ‘marketdata/20230201.OP.csv.gz’ saved [13236391/13236391]
#
# --2024-03-04 11:09:51--  https://datasets.tardis.dev/v1/bybit/trades/2023/02/01/MATICUSDT.csv.gz
# Resolving datasets.tardis.dev (datasets.tardis.dev)... 104.18.40.205, 172.64.147.51
# Connecting to datasets.tardis.dev (datasets.tardis.dev)|104.18.40.205|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5878913 (5.6M) [text/csv]
# Saving to: ‘marketdata/20230201.MATIC.csv.gz’
#
# marketdata/20230201 100%[===================>]   5.61M  10.2MB/s    in 0.6s
#
# 2024-03-04 11:09:52 (10.2 MB/s) - ‘marketdata/20230201.MATIC.csv.gz’ saved [5878913/5878913]
#
# --2024-03-04 11:09:52--  https://datasets.tardis.dev/v1/bybit/trades/2023/03/01/XRPUSDT.csv.gz
# Resolving datasets.tardis.dev (datasets.tardis.dev)... 104.18.40.205, 172.64.147.51
# Connecting to datasets.tardis.dev (datasets.tardis.dev)|104.18.40.205|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2636031 (2.5M) [text/csv]
# Saving to: ‘marketdata/20230301.XRP.csv.gz’
#
# marketdata/20230301 100%[===================>]   2.51M  9.07MB/s    in 0.3s
#
# 2024-03-04 11:09:53 (9.07 MB/s) - ‘marketdata/20230301.XRP.csv.gz’ saved [2636031/2636031]
#
# --2024-03-04 11:09:53--  https://datasets.tardis.dev/v1/bybit/trades/2023/03/01/OPUSDT.csv.gz
# Resolving datasets.tardis.dev (datasets.tardis.dev)... 104.18.40.205, 172.64.147.51
# Connecting to datasets.tardis.dev (datasets.tardis.dev)|104.18.40.205|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7321791 (7.0M) [text/csv]
# Saving to: ‘marketdata/20230301.OP.csv.gz’
#
# marketdata/20230301 100%[===================>]   6.98M  4.48MB/s    in 1.6s
#
# 2024-03-04 11:09:55 (4.48 MB/s) - ‘marketdata/20230301.OP.csv.gz’ saved [7321791/7321791]
#
# --2024-03-04 11:09:55--  https://datasets.tardis.dev/v1/bybit/trades/2023/03/01/MATICUSDT.csv.gz
# Resolving datasets.tardis.dev (datasets.tardis.dev)... 104.18.40.205, 172.64.147.51
# Connecting to datasets.tardis.dev (datasets.tardis.dev)|104.18.40.205|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5194590 (5.0M) [text/csv]
# Saving to: ‘marketdata/20230301.MATIC.csv.gz’
#
# marketdata/20230301 100%[===================>]   4.95M  4.18MB/s    in 1.2s
#
# 2024-03-04 11:09:57 (4.18 MB/s) - ‘marketdata/20230301.MATIC.csv.gz’ saved [5194590/5194590]
#
# --2024-03-04 11:09:57--  https://datasets.tardis.dev/v1/bybit/trades/2023/04/01/XRPUSDT.csv.gz
# Resolving datasets.tardis.dev (datasets.tardis.dev)... 104.18.40.205, 172.64.147.51
# Connecting to datasets.tardis.dev (datasets.tardis.dev)|104.18.40.205|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14327821 (14M) [text/csv]
# Saving to: ‘marketdata/20230401.XRP.csv.gz’
#
# marketdata/20230401 100%[===================>]  13.66M  6.48MB/s    in 2.1s
#
# 2024-03-04 11:09:59 (6.48 MB/s) - ‘marketdata/20230401.XRP.csv.gz’ saved [14327821/14327821]
#
# --2024-03-04 11:10:00--  https://datasets.tardis.dev/v1/bybit/trades/2023/04/01/OPUSDT.csv.gz
# Resolving datasets.tardis.dev (datasets.tardis.dev)... 104.18.40.205, 172.64.147.51
# Connecting to datasets.tardis.dev (datasets.tardis.dev)|104.18.40.205|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2766235 (2.6M) [text/csv]
# Saving to: ‘marketdata/20230401.OP.csv.gz’
#
# marketdata/20230401 100%[===================>]   2.64M  7.49MB/s    in 0.4s
#
# 2024-03-04 11:10:01 (7.49 MB/s) - ‘marketdata/20230401.OP.csv.gz’ saved [2766235/2766235]
#
# --2024-03-04 11:10:01--  https://datasets.tardis.dev/v1/bybit/trades/2023/04/01/MATICUSDT.csv.gz
# Resolving datasets.tardis.dev (datasets.tardis.dev)... 104.18.40.205, 172.64.147.51
# Connecting to datasets.tardis.dev (datasets.tardis.dev)|104.18.40.205|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2635501 (2.5M) [text/csv]
# Saving to: ‘marketdata/20230401.MATIC.csv.gz’
#
# marketdata/20230401 100%[===================>]   2.51M  6.98MB/s    in 0.4s
#
# 2024-03-04 11:10:02 (6.98 MB/s) - ‘marketdata/20230401.MATIC.csv.gz’ saved [2635501/2635501]
#
# --2024-03-04 11:10:02--  https://datasets.tardis.dev/v1/bybit/trades/2023/05/01/XRPUSDT.csv.gz
# Resolving datasets.tardis.dev (datasets.tardis.dev)... 104.18.40.205, 172.64.147.51
# Connecting to datasets.tardis.dev (datasets.tardis.dev)|104.18.40.205|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12527833 (12M) [text/csv]
# Saving to: ‘marketdata/20230501.XRP.csv.gz’
#
# marketdata/20230501 100%[===================>]  11.95M  5.28MB/s    in 2.3s
#
# 2024-03-04 11:10:04 (5.28 MB/s) - ‘marketdata/20230501.XRP.csv.gz’ saved [12527833/12527833]
#
# --2024-03-04 11:10:04--  https://datasets.tardis.dev/v1/bybit/trades/2023/05/01/OPUSDT.csv.gz
# Resolving datasets.tardis.dev (datasets.tardis.dev)... 104.18.40.205, 172.64.147.51
# Connecting to datasets.tardis.dev (datasets.tardis.dev)|104.18.40.205|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6170546 (5.9M) [text/csv]
# Saving to: ‘marketdata/20230501.OP.csv.gz’
#
# marketdata/20230501 100%[===================>]   5.88M  4.69MB/s    in 1.3s
#
# 2024-03-04 11:10:06 (4.69 MB/s) - ‘marketdata/20230501.OP.csv.gz’ saved [6170546/6170546]
#
# --2024-03-04 11:10:06--  https://datasets.tardis.dev/v1/bybit/trades/2023/05/01/MATICUSDT.csv.gz
# Resolving datasets.tardis.dev (datasets.tardis.dev)... 172.64.147.51, 104.18.40.205
# Connecting to datasets.tardis.dev (datasets.tardis.dev)|172.64.147.51|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4007706 (3.8M) [text/csv]
# Saving to: ‘marketdata/20230501.MATIC.csv.gz’
#
# marketdata/20230501 100%[===================>]   3.82M  8.22MB/s    in 0.5s
#
# 2024-03-04 11:10:07 (8.22 MB/s) - ‘marketdata/20230501.MATIC.csv.gz’ saved [4007706/4007706]
#
# --2024-03-04 11:10:07--  https://datasets.tardis.dev/v1/bybit/trades/2023/06/01/XRPUSDT.csv.gz
# Resolving datasets.tardis.dev (datasets.tardis.dev)... 172.64.147.51, 104.18.40.205
# Connecting to datasets.tardis.dev (datasets.tardis.dev)|172.64.147.51|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14888468 (14M) [text/csv]
# Saving to: ‘marketdata/20230601.XRP.csv.gz’
#
# marketdata/20230601 100%[===================>]  14.20M  8.58MB/s    in 1.7s
#
# 2024-03-04 11:10:09 (8.58 MB/s) - ‘marketdata/20230601.XRP.csv.gz’ saved [14888468/14888468]
#
# --2024-03-04 11:10:09--  https://datasets.tardis.dev/v1/bybit/trades/2023/06/01/OPUSDT.csv.gz
# Resolving datasets.tardis.dev (datasets.tardis.dev)... 172.64.147.51, 104.18.40.205
# Connecting to datasets.tardis.dev (datasets.tardis.dev)|172.64.147.51|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4880125 (4.7M) [text/csv]
# Saving to: ‘marketdata/20230601.OP.csv.gz’
#
# marketdata/20230601 100%[===================>]   4.65M  7.35MB/s    in 0.6s
#
# 2024-03-04 11:10:10 (7.35 MB/s) - ‘marketdata/20230601.OP.csv.gz’ saved [4880125/4880125]
#
# --2024-03-04 11:10:10--  https://datasets.tardis.dev/v1/bybit/trades/2023/06/01/MATICUSDT.csv.gz
# Resolving datasets.tardis.dev (datasets.tardis.dev)... 172.64.147.51, 104.18.40.205
# Connecting to datasets.tardis.dev (datasets.tardis.dev)|172.64.147.51|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1917699 (1.8M) [text/csv]
# Saving to: ‘marketdata/20230601.MATIC.csv.gz’
#
# marketdata/20230601 100%[===================>]   1.83M  8.02MB/s    in 0.2s
#
# 2024-03-04 11:10:11 (8.02 MB/s) - ‘marketdata/20230601.MATIC.csv.gz’ saved [1917699/1917699]
#
# --2024-03-04 11:10:11--  https://datasets.tardis.dev/v1/bybit/trades/2023/07/01/XRPUSDT.csv.gz
# Resolving datasets.tardis.dev (datasets.tardis.dev)... 172.64.147.51, 104.18.40.205
# Connecting to datasets.tardis.dev (datasets.tardis.dev)|172.64.147.51|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4760234 (4.5M) [text/csv]
# Saving to: ‘marketdata/20230701.XRP.csv.gz’
#
# marketdata/20230701 100%[===================>]   4.54M  6.95MB/s    in 0.7s
#
# 2024-03-04 11:10:12 (6.95 MB/s) - ‘marketdata/20230701.XRP.csv.gz’ saved [4760234/4760234]
#
# --2024-03-04 11:10:12--  https://datasets.tardis.dev/v1/bybit/trades/2023/07/01/OPUSDT.csv.gz
# Resolving datasets.tardis.dev (datasets.tardis.dev)... 172.64.147.51, 104.18.40.205
# Connecting to datasets.tardis.dev (datasets.tardis.dev)|172.64.147.51|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4510964 (4.3M) [text/csv]
# Saving to: ‘marketdata/20230701.OP.csv.gz’
#
# marketdata/20230701 100%[===================>]   4.30M  9.41MB/s    in 0.5s
#
# 2024-03-04 11:10:13 (9.41 MB/s) - ‘marketdata/20230701.OP.csv.gz’ saved [4510964/4510964]
#
# --2024-03-04 11:10:13--  https://datasets.tardis.dev/v1/bybit/trades/2023/07/01/MATICUSDT.csv.gz
# Resolving datasets.tardis.dev (datasets.tardis.dev)... 172.64.147.51, 104.18.40.205
# Connecting to datasets.tardis.dev (datasets.tardis.dev)|172.64.147.51|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3995947 (3.8M) [text/csv]
# Saving to: ‘marketdata/20230701.MATIC.csv.gz’
#
# marketdata/20230701 100%[===================>]   3.81M  9.24MB/s    in 0.4s
#
# 2024-03-04 11:10:14 (9.24 MB/s) - ‘marketdata/20230701.MATIC.csv.gz’ saved [3995947/3995947]
#
# --2024-03-04 11:10:14--  https://datasets.tardis.dev/v1/bybit/trades/2023/08/01/XRPUSDT.csv.gz
# Resolving datasets.tardis.dev (datasets.tardis.dev)... 172.64.147.51, 104.18.40.205
# Connecting to datasets.tardis.dev (datasets.tardis.dev)|172.64.147.51|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10929501 (10M) [text/csv]
# Saving to: ‘marketdata/20230801.XRP.csv.gz’
#
# marketdata/20230801 100%[===================>]  10.42M  10.2MB/s    in 1.0s
#
# 2024-03-04 11:10:16 (10.2 MB/s) - ‘marketdata/20230801.XRP.csv.gz’ saved [10929501/10929501]
#
# --2024-03-04 11:10:16--  https://datasets.tardis.dev/v1/bybit/trades/2023/08/01/OPUSDT.csv.gz
# Resolving datasets.tardis.dev (datasets.tardis.dev)... 172.64.147.51, 104.18.40.205
# Connecting to datasets.tardis.dev (datasets.tardis.dev)|172.64.147.51|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9382439 (8.9M) [text/csv]
# Saving to: ‘marketdata/20230801.OP.csv.gz’
#
# marketdata/20230801 100%[===================>]   8.95M  10.6MB/s    in 0.8s
#
# 2024-03-04 11:10:17 (10.6 MB/s) - ‘marketdata/20230801.OP.csv.gz’ saved [9382439/9382439]
#
# --2024-03-04 11:10:17--  https://datasets.tardis.dev/v1/bybit/trades/2023/08/01/MATICUSDT.csv.gz
# Resolving datasets.tardis.dev (datasets.tardis.dev)... 172.64.147.51, 104.18.40.205
# Connecting to datasets.tardis.dev (datasets.tardis.dev)|172.64.147.51|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4290486 (4.1M) [text/csv]
# Saving to: ‘marketdata/20230801.MATIC.csv.gz’
#
# marketdata/20230801 100%[===================>]   4.09M  7.96MB/s    in 0.5s
#
# 2024-03-04 11:10:18 (7.96 MB/s) - ‘marketdata/20230801.MATIC.csv.gz’ saved [4290486/4290486]
#
# --2024-03-04 11:10:18--  https://datasets.tardis.dev/v1/bybit/trades/2023/09/01/XRPUSDT.csv.gz
# Resolving datasets.tardis.dev (datasets.tardis.dev)... 172.64.147.51, 104.18.40.205
# Connecting to datasets.tardis.dev (datasets.tardis.dev)|172.64.147.51|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5376744 (5.1M) [text/csv]
# Saving to: ‘marketdata/20230901.XRP.csv.gz’
#
# marketdata/20230901 100%[===================>]   5.13M  6.73MB/s    in 0.8s
#
# 2024-03-04 11:10:20 (6.73 MB/s) - ‘marketdata/20230901.XRP.csv.gz’ saved [5376744/5376744]
#
# --2024-03-04 11:10:20--  https://datasets.tardis.dev/v1/bybit/trades/2023/09/01/OPUSDT.csv.gz
# Resolving datasets.tardis.dev (datasets.tardis.dev)... 172.64.147.51, 104.18.40.205
# Connecting to datasets.tardis.dev (datasets.tardis.dev)|172.64.147.51|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3701235 (3.5M) [text/csv]
# Saving to: ‘marketdata/20230901.OP.csv.gz’
#
# marketdata/20230901 100%[===================>]   3.53M  7.59MB/s    in 0.5s
#
# 2024-03-04 11:10:21 (7.59 MB/s) - ‘marketdata/20230901.OP.csv.gz’ saved [3701235/3701235]
#
# --2024-03-04 11:10:21--  https://datasets.tardis.dev/v1/bybit/trades/2023/09/01/MATICUSDT.csv.gz
# Resolving datasets.tardis.dev (datasets.tardis.dev)... 172.64.147.51, 104.18.40.205
# Connecting to datasets.tardis.dev (datasets.tardis.dev)|172.64.147.51|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2284395 (2.2M) [text/csv]
# Saving to: ‘marketdata/20230901.MATIC.csv.gz’
#
# marketdata/20230901 100%[===================>]   2.18M  7.32MB/s    in 0.3s
#
# 2024-03-04 11:10:21 (7.32 MB/s) - ‘marketdata/20230901.MATIC.csv.gz’ saved [2284395/2284395]
#
# --2024-03-04 11:10:21--  https://datasets.tardis.dev/v1/bybit/trades/2023/10/01/XRPUSDT.csv.gz
# Resolving datasets.tardis.dev (datasets.tardis.dev)... 172.64.147.51, 104.18.40.205
# Connecting to datasets.tardis.dev (datasets.tardis.dev)|172.64.147.51|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4180446 (4.0M) [text/csv]
# Saving to: ‘marketdata/20231001.XRP.csv.gz’
#
# marketdata/20231001 100%[===================>]   3.99M  7.69MB/s    in 0.5s
#
# 2024-03-04 11:10:22 (7.69 MB/s) - ‘marketdata/20231001.XRP.csv.gz’ saved [4180446/4180446]
#
# --2024-03-04 11:10:22--  https://datasets.tardis.dev/v1/bybit/trades/2023/10/01/OPUSDT.csv.gz
# Resolving datasets.tardis.dev (datasets.tardis.dev)... 172.64.147.51, 104.18.40.205
# Connecting to datasets.tardis.dev (datasets.tardis.dev)|172.64.147.51|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2503777 (2.4M) [text/csv]
# Saving to: ‘marketdata/20231001.OP.csv.gz’
#
# marketdata/20231001 100%[===================>]   2.39M  6.85MB/s    in 0.3s
#
# 2024-03-04 11:10:23 (6.85 MB/s) - ‘marketdata/20231001.OP.csv.gz’ saved [2503777/2503777]
#
# --2024-03-04 11:10:23--  https://datasets.tardis.dev/v1/bybit/trades/2023/10/01/MATICUSDT.csv.gz
# Resolving datasets.tardis.dev (datasets.tardis.dev)... 172.64.147.51, 104.18.40.205
# Connecting to datasets.tardis.dev (datasets.tardis.dev)|172.64.147.51|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3914466 (3.7M) [text/csv]
# Saving to: ‘marketdata/20231001.MATIC.csv.gz’
#
# marketdata/20231001 100%[===================>]   3.73M  8.96MB/s    in 0.4s
#
# 2024-03-04 11:10:24 (8.96 MB/s) - ‘marketdata/20231001.MATIC.csv.gz’ saved [3914466/3914466]
#
# --2024-03-04 11:10:24--  https://datasets.tardis.dev/v1/bybit/trades/2023/11/01/XRPUSDT.csv.gz
# Resolving datasets.tardis.dev (datasets.tardis.dev)... 172.64.147.51, 104.18.40.205
# Connecting to datasets.tardis.dev (datasets.tardis.dev)|172.64.147.51|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14717207 (14M) [text/csv]
# Saving to: ‘marketdata/20231101.XRP.csv.gz’
#
# marketdata/20231101 100%[===================>]  14.04M  9.70MB/s    in 1.4s
#
# 2024-03-04 11:10:27 (9.70 MB/s) - ‘marketdata/20231101.XRP.csv.gz’ saved [14717207/14717207]
#
# --2024-03-04 11:10:27--  https://datasets.tardis.dev/v1/bybit/trades/2023/11/01/OPUSDT.csv.gz
# Resolving datasets.tardis.dev (datasets.tardis.dev)... 172.64.147.51, 104.18.40.205
# Connecting to datasets.tardis.dev (datasets.tardis.dev)|172.64.147.51|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4288724 (4.1M) [text/csv]
# Saving to: ‘marketdata/20231101.OP.csv.gz’
#
# marketdata/20231101 100%[===================>]   4.09M  6.66MB/s    in 0.6s
#
# 2024-03-04 11:10:28 (6.66 MB/s) - ‘marketdata/20231101.OP.csv.gz’ saved [4288724/4288724]
#
# --2024-03-04 11:10:28--  https://datasets.tardis.dev/v1/bybit/trades/2023/11/01/MATICUSDT.csv.gz
# Resolving datasets.tardis.dev (datasets.tardis.dev)... 172.64.147.51, 104.18.40.205
# Connecting to datasets.tardis.dev (datasets.tardis.dev)|172.64.147.51|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5295589 (5.0M) [text/csv]
# Saving to: ‘marketdata/20231101.MATIC.csv.gz’
#
# marketdata/20231101 100%[===================>]   5.05M  7.63MB/s    in 0.7s
#
# 2024-03-04 11:10:29 (7.63 MB/s) - ‘marketdata/20231101.MATIC.csv.gz’ saved [5295589/5295589]
#
# --2024-03-04 11:10:29--  https://datasets.tardis.dev/v1/bybit/trades/2023/12/01/XRPUSDT.csv.gz
# Resolving datasets.tardis.dev (datasets.tardis.dev)... 172.64.147.51, 104.18.40.205
# Connecting to datasets.tardis.dev (datasets.tardis.dev)|172.64.147.51|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3390916 (3.2M) [text/csv]
# Saving to: ‘marketdata/20231201.XRP.csv.gz’
#
# marketdata/20231201 100%[===================>]   3.23M  8.62MB/s    in 0.4s
#
# 2024-03-04 11:10:30 (8.62 MB/s) - ‘marketdata/20231201.XRP.csv.gz’ saved [3390916/3390916]
#
# --2024-03-04 11:10:30--  https://datasets.tardis.dev/v1/bybit/trades/2023/12/01/OPUSDT.csv.gz
# Resolving datasets.tardis.dev (datasets.tardis.dev)... 172.64.147.51, 104.18.40.205
# Connecting to datasets.tardis.dev (datasets.tardis.dev)|172.64.147.51|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3277239 (3.1M) [text/csv]
# Saving to: ‘marketdata/20231201.OP.csv.gz’
#
# marketdata/20231201 100%[===================>]   3.12M  9.67MB/s    in 0.3s
#
# 2024-03-04 11:10:31 (9.67 MB/s) - ‘marketdata/20231201.OP.csv.gz’ saved [3277239/3277239]
#
# --2024-03-04 11:10:31--  https://datasets.tardis.dev/v1/bybit/trades/2023/12/01/MATICUSDT.csv.gz
# Resolving datasets.tardis.dev (datasets.tardis.dev)... 172.64.147.51, 104.18.40.205
# Connecting to datasets.tardis.dev (datasets.tardis.dev)|172.64.147.51|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3901879 (3.7M) [text/csv]
# Saving to: ‘marketdata/20231201.MATIC.csv.gz’
#
# marketdata/20231201 100%[===================>]   3.72M  9.00MB/s    in 0.4s
#
# 2024-03-04 11:10:32 (9.00 MB/s) - ‘marketdata/20231201.MATIC.csv.gz’ saved [3901879/3901879]

# %%
# !mv marketdata/ ..

# %% [markdown]
# # Inline Signal Set Calculator

# %%
import numpy as np

class SignalSetCalculator:
    def __init__(self):
        self.lastTradePrice: float = np.nan
        self.lastTradeAmount: float = np.nan
        self.dTradePrice: float = 0.
        self.dTradeAmount: float = 0.

    def update(self, message: dict):
        px = message['price']
        amt = message['amount']

        self.dTradePrice = px - self.lastTradePrice
        self.dTradeAmount = amt - self.lastTradeAmount
        self.lastTradePrice = px
        self.lastTradeAmount = amt
    
    def get(self):
        return np.array([
            self.lastTradePrice, self.lastTradeAmount, self.dTradePrice, self.dTradeAmount,
            ], dtype = np.float64)

# %% [markdown]
# # Ops Driven Calculator

# %%
import numpy as np

class InputOp:
    """ reads a message from the input """
    def __init__(self):
        self.dtype = dict
        self.value = {}
        self.inputs = []

    def update(self, message: dict):
        self.value = message

class GetOp:
    """ reads a field from the input message """
    def __init__(self, field: str, dtype: np.dtype, inputs: list):
        self.field = field
        self.dtype = dtype
        self.value = dtype()
        self.inputs = inputs

    def update(self, message: dict):
        self.value = self.dtype(message[self.field])

class DiffOp:
    """ computes the difference between the current and last value """
    def __init__(self, dtype: np.dtype, inputs: list):
        self.dtype = dtype
        self.value = dtype()
        self.last = dtype()
        self.inputs = inputs
    
    def update(self, x):
        self.value = x - self.last
        self.last = x

class SignalSetCalculatorOps:
    def __init__(self):
        self.input = InputOp()
        self.lastTradePrice = GetOp("price", np.float64, ["input"])
        self.lastTradeAmount = GetOp("amount", np.float64, ["input"])
        self.dTradePrice = DiffOp(np.float64, ["lastTradePrice"])
        self.dTradeAmount = DiffOp(np.float64, ["lastTradeAmount"])

    def updatesignal(self, signal):
        signal.update(*[getattr(self, x).value for x in signal.inputs])

    def update(self, message: dict):
        self.input.update(message)
        self.updatesignal(self.lastTradePrice)
        self.updatesignal(self.lastTradeAmount)
        self.updatesignal(self.dTradePrice)
        self.updatesignal(self.dTradeAmount)

    def get(self):
        return np.array([
            self.lastTradePrice.value, self.lastTradeAmount.value, self.dTradePrice.value, self.dTradeAmount.value,
            ], dtype=np.float64)

# %% [markdown]
# # Comparing the two approaches
#
# They should produce same result. Want to see how fast they are as well.

# %%
import pandas as pd
import numpy as np

data=pd.read_csv("../marketdata/20231101.OP.csv.gz", compression="gzip"); data
# Out:
#        exchange  symbol         timestamp   local_timestamp  \
# 0         bybit  OPUSDT  1698796801797000  1698796801835449
# 1         bybit  OPUSDT  1698796801804000  1698796801842170
# 2         bybit  OPUSDT  1698796801804000  1698796801842170
# 3         bybit  OPUSDT  1698796806911000  1698796806949468
# 4         bybit  OPUSDT  1698796809007000  1698796809044363
# ...         ...     ...               ...               ...
# 136125    bybit  OPUSDT  1698883190808000  1698883190853743
# 136126    bybit  OPUSDT  1698883190815000  1698883190860478
# 136127    bybit  OPUSDT  1698883190815000  1698883190860478
# 136128    bybit  OPUSDT  1698883190815000  1698883190860478
# 136129    bybit  OPUSDT  1698883192974000  1698883193020791
#
#                                           id  side   price  amount
# 0       6487eaa4-ab7e-534d-b5a1-6d9ee482c8a4  sell  1.3961   250.0
# 1       7e7537e0-aba4-52f6-8636-90a78e1e035f  sell  1.3961   150.0
# 2       bd3dd448-527f-541a-99d9-161d9599d7d3  sell  1.3961    11.7
# 3       b40d10f4-1efd-5923-be61-308ab947d073  sell  1.3960   115.6
# 4       99bb5885-ff82-559d-88b0-c98cb538d1c2   buy  1.3961    22.2
# ...                                      ...   ...     ...     ...
# 136125  d93744d8-62b5-5d60-be9a-0e2efa12da2e   buy  1.4379   219.9
# 136126  4e716785-0fa5-5ffc-be29-9a05e252d985   buy  1.4379    15.6
# 136127  b4bc5d5b-4a83-5dcd-b20c-6e98f3943893   buy  1.4379    28.0
# 136128  81536c25-4cca-545f-a440-137b296277dd   buy  1.4379   298.6
# 136129  74e62133-399c-5a99-947c-5f67c1fbffe1   buy  1.4380    61.0
#
# [136130 rows x 8 columns]

# %%
def testSignalCalculator():
    fc = SignalSetCalculator()
    i=0
    result1=[]
    for row in data.to_dict(orient='records') :
        i += 1
        fc.update(row)
        if i%1000 == 0: result1.append(fc.get())
    return result1
# %timeit testSignalCalculator()
# Out:
# 214 ms ± 1.17 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
def testSignalCalculatorOps():
    fc = SignalSetCalculatorOps()
    i=0
    result=[]
    for row in data.to_dict(orient='records') :
        i += 1
        fc.update(row)
        if i%1000 == 0: result.append(fc.get())
    return result
# %timeit testSignalCalculatorOps()
# Out:
# 381 ms ± 2.21 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# We see that the later approach is about twice as slow. Is the slowness worth it?

# %%
def are_lists_of_arrays_close(list1, list2, rtol=1e-05, atol=1e-08):
    if len(list1) != len(list2):
        return False
    for array1, array2 in zip(list1, list2):
        if not np.allclose(array1, array2):
            return False
    return True


are_lists_of_arrays_close(testSignalCalculator(), testSignalCalculatorOps())
# Out:
# True

# %% [markdown]
# But at least both approaches are returning the same result :)

# %% [markdown]
# # Alternative - Using array calculations for backtesting

# %%
def testSignalCalculatorNumpy(): 
    d = data.copy()
    d['dTradePrice'] = d.price.diff()
    d['dTradeAmount'] = d.amount.diff()
    result = d[['price','amount', 'dTradePrice', 'dTradeAmount']].iloc[999::1000]
    return [row for row in result.to_numpy()]
# %timeit testSignalCalculatorNumpy()
# Out:
# 4.76 ms ± 113 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
are_lists_of_arrays_close(testSignalCalculator(), testSignalCalculatorNumpy())
# Out:
# True

# %% [markdown]
# We see that direct numpy vector operations are way faster than any iterative looping using python.
#
# About 50x faster than SignalSetCalculator() and about 100x faster than SignalSetCalculatorOps()

# %% [markdown]
# # Conculsion
#
# For back-testing, we nearly certainly want to use numpy for calculating signals.

# %% [markdown]
# # Faster Execution

# %%
# %pip install numba
# Out:
# Collecting numba
#   Obtaining dependency information for numba from https://files.pythonhosted.org/packages/ef/20/94ef7b3afee76f47f3ad2d9dfc64f5cb29a365df00e5c563e7518e761bc0/numba-0.59.0-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Using cached numba-0.59.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.7 kB)
# Collecting llvmlite<0.43,>=0.42.0dev0 (from numba)
#   Obtaining dependency information for llvmlite<0.43,>=0.42.0dev0 from https://files.pythonhosted.org/packages/ba/3a/286d01191e62ddbe645d4a3f1e0d96106a98d3fd7f82441d20ffe93ab669/llvmlite-0.42.0-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Using cached llvmlite-0.42.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (4.8 kB)
# Requirement already satisfied: numpy<1.27,>=1.22 in /Users/jstranik/Developer/manafund/mana-signals/.venv/lib/python3.11/site-packages (from numba) (1.26.4)
# Using cached numba-0.59.0-cp311-cp311-macosx_11_0_arm64.whl (2.6 MB)
# Using cached llvmlite-0.42.0-cp311-cp311-macosx_11_0_arm64.whl (28.8 MB)
# Installing collected packages: llvmlite, numba
# Successfully installed llvmlite-0.42.0 numba-0.59.0
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from numba import njit
@njit
def testSignalCalculator2():
    fc = SignalSetCalculator()
    i=0
    result1=[]
    for row in data.to_dict(orient='records') :
        i += 1
        fc.update(row)
        if i%1000 == 0: result1.append(fc.get())
    return result1
# %timeit testSignalCalculator2()
# Out:
# ---------------------------------------------------------------------------
# TypingError                               Traceback (most recent call last)
# Cell In[77], line 12
#      10         if i%1000 == 0: result1.append(fc.get())
#      11     return result1
# ---> 12 get_ipython().run_line_magic('timeit', 'testSignalCalculator2()')
#
# File ~/Developer/manafund/mana-signals/.venv/lib/python3.11/site-packages/IPython/core/interactiveshell.py:2480, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2478     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2479 with self.builtin_trap:
# -> 2480     result = fn(*args, **kwargs)
#    2482 # The code below prevents the output from being displayed
#    2483 # when using magics with decorator @output_can_be_silenced
#    2484 # when the last Python token in the expression is a ';'.
#    2485 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/Developer/manafund/mana-signals/.venv/lib/python3.11/site-packages/IPython/core/magics/execution.py:1185, in ExecutionMagics.timeit(self, line, cell, local_ns)
#    1183 for index in range(0, 10):
#    1184     number = 10 ** index
# -> 1185     time_number = timer.timeit(number)
#    1186     if time_number >= 0.2:
#    1187         break
#
# File ~/Developer/manafund/mana-signals/.venv/lib/python3.11/site-packages/IPython/core/magics/execution.py:173, in Timer.timeit(self, number)
#     171 gc.disable()
#     172 try:
# --> 173     timing = self.inner(it, self.timer)
#     174 finally:
#     175     if gcold:
#
# File <magic-timeit>:1, in inner(_it, _timer)
#
# File ~/Developer/manafund/mana-signals/.venv/lib/python3.11/site-packages/numba/core/dispatcher.py:468, in _DispatcherBase._compile_for_args(self, *args, **kws)
#     464         msg = (f"{str(e).rstrip()} \n\nThis error may have been caused "
#     465                f"by the following argument(s):\n{args_str}\n")
#     466         e.patch_message(msg)
# --> 468     error_rewrite(e, 'typing')
#     469 except errors.UnsupportedError as e:
#     470     # Something unsupported is present in the user code, add help info
#     471     error_rewrite(e, 'unsupported_error')
#
# File ~/Developer/manafund/mana-signals/.venv/lib/python3.11/site-packages/numba/core/dispatcher.py:409, in _DispatcherBase._compile_for_args.<locals>.error_rewrite(e, issue_type)
#     407     raise e
#     408 else:
# --> 409     raise e.with_traceback(None)
#
# TypingError: Failed in nopython mode pipeline (step: nopython frontend)
# Untyped global name 'SignalSetCalculator': Cannot determine Numba type of <class 'type'>
#
# File "../../../../../../var/folders/l_/l7636tpj5zzd5cx3pwzdd8k00000gn/T/ipykernel_77153/98501214.py", line 4:
# <source missing, REPL/exec in use?>

# %% [markdown]
# Above does not work since numba can only compile functions, not python classes.
